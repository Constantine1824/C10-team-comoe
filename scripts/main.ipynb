# %%
from google.colab import userdata
from huggingface_hub import login
import sys
import os

os.environ['GITHUB_TOKEN'] = userdata.get('GITHUB_TOKEN')
# !git clone https://$GITHUB_TOKEN@github.com/Constantine1824/C10-team-comoe.git
sys.path.append('/content/C10-team-comoe')
login(token=userdata.get('HF_TOKEN'))
# %cd /content/C10-team-comoe/scripts
#!git pull origin main
# Out:
# /content/TRI-AI-SLM

# %%
import importlib
importlib.invalidate_caches()

import importlib.util
print(importlib.util.find_spec('finetune'))
# Out:
# ModuleSpec(name='rag', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f426dea0350>, origin='/content/TRI-AI-SLM/rag/__init__.py', submodule_search_locations=['/content/TRI-AI-SLM/rag'])

# %%
# !pip install trl peft bitsandbytes
import numpy as np
import pandas as pd
from finetune.trainer import collate_fn, finetune, evaluate, prepare_data
from format import format_train_data, format_test_data
# Out:
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 33.4MB
# tokenizer.json: downloading bytes:           |  0.00B
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]

# %%
data = pd.read_csv('../data/train_qa.csv')
data.head()
# Out:
#                                             question               topic  \
# 0  BP readings improved — skip tablets this weekend?     chronic_disease
# 1         Pregnant and always tired — common workup?     maternal_health
# 2  When should someone with flu-like symptoms sta...  infectious_disease
# 3        How do I manage type 2 diabetes day to day?     chronic_disease
# 4           Feverish toddler — paracetamol cautions?   medication_safety
#
#    care_setting population  document_id  \
# 0  primary_care      adult  doc_chr_002
# 1  primary_care   pregnant  doc_mat_003
# 2     community    general  doc_inf_002
# 3  primary_care      adult  doc_chr_001
# 4          home      child  doc_med_003
#
#                                     reference_answer  QuestionId
# 0  No — never stop antihypertensives abruptly wit...           1
# 1  Screen for anaemia and treat with iron plus di...           2
# 2  While febrile to reduce spread at school or work.           3
# 3  Balance meals, stay active, take medicines as ...           4
# 4  Use weight-based doses and avoid exceeding dai...           5

# %%
doc = pd.read_csv('../data/documents.csv')
doc.head()
# Out:
#    document_id                                   title               topic  \
# 0  doc_chr_001         Type 2 diabetes self-management     chronic_disease
# 1  doc_chr_002         Hypertension lifestyle measures     chronic_disease
# 2  doc_chr_003               Asthma action plan basics     chronic_disease
# 3  doc_inf_001     Malaria prevention in endemic areas  infectious_disease
# 4  doc_inf_002  Hand hygiene and respiratory etiquette  infectious_disease
#
#    care_setting population                                               text  \
# 0  primary_care      adult  Type 2 diabetes management combines balanced m...
# 1  primary_care      adult  Lowering dietary salt, maintaining healthy wei...
# 2  primary_care      child  Children with asthma should use a written acti...
# 3     community    general  Sleep under insecticide-treated nets, eliminat...
# 4     community    general  Wash hands with soap for at least twenty secon...
#
#       origin  source_url  license
# 0  synthetic         NaN  CC0-1.0
# 1  synthetic         NaN  CC0-1.0
# 2  synthetic         NaN  CC0-1.0
# 3  synthetic         NaN  CC0-1.0
# 4  synthetic         NaN  CC0-1.0

# %%
data = data.merge(doc[['document_id', 'text']], on='document_id', how='left')
data = data.rename(columns={'text':'context'})
data.head()
# Out:
#                                             question               topic  \
# 0  BP readings improved — skip tablets this weekend?     chronic_disease
# 1         Pregnant and always tired — common workup?     maternal_health
# 2  When should someone with flu-like symptoms sta...  infectious_disease
# 3        How do I manage type 2 diabetes day to day?     chronic_disease
# 4           Feverish toddler — paracetamol cautions?   medication_safety
#
#    care_setting population  document_id  \
# 0  primary_care      adult  doc_chr_002
# 1  primary_care   pregnant  doc_mat_003
# 2     community    general  doc_inf_002
# 3  primary_care      adult  doc_chr_001
# 4          home      child  doc_med_003
#
#                                     reference_answer  QuestionId  \
# 0  No — never stop antihypertensives abruptly wit...           1
# 1  Screen for anaemia and treat with iron plus di...           2
# 2  While febrile to reduce spread at school or work.           3
# 3  Balance meals, stay active, take medicines as ...           4
# 4  Use weight-based doses and avoid exceeding dai...           5
#
#                                              context
# 0  Lowering dietary salt, maintaining healthy wei...
# 1  Anaemia increases fatigue and adverse birth ou...
# 2  Wash hands with soap for at least twenty secon...
# 3  Type 2 diabetes management combines balanced m...
# 4  Use weight-based paediatric paracetamol dosing...

# %%
from datasets import Dataset
from rag.retriever import HybridRetriever

retriever = HybridRetriever()
test_data = pd.read_csv('../data/test_questions.csv')
train_data, test_data, _ = prepare_data(train_data, test_data, retriever)
# Out:
# Map:   0%|          | 0/43 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11 [00:00<?, ? examples/s]

# %%
trainer = finetune(train_data)
eval = evaluate(trainer, test_data, batch_size=11)
eval
# Out:
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.55k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 33.4MB
# tokenizer.json: downloading bytes:           |  0.00B
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 1, 'bos_token_id': 2, 'pad_token_id': 0}.
#     <div>
#
#       <progress value='2' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2/60 : < :, Epoch 0.36/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='6' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6/60 04:35 < 1:02:04, 0.01 it/s, Epoch 1.73/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4</td>
#       <td>3.169994</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
test_df = pd.read_csv('data/test_questions.csv')
test_df.head()
# Out:
#    QuestionId                                      question  \
# 0        1001             How is pregnancy anaemia managed?
# 1        1002        Fever in a two-month-old — what to do?
# 2        1003     Pregnancy symptoms needing urgent review?
# 3        1004  Teen refuses school citing panic — approach?
# 4        1005             How can families prevent malaria?
#
#                   topic  care_setting population
# 0       maternal_health  primary_care   pregnant
# 1      emergency_triage      hospital     infant
# 2       maternal_health  primary_care   pregnant
# 3  mental_health_basics        school      child
# 4    infectious_disease     community    general

# %%
qid = test_df['QuestionId']
qid
# Out:
# 0     1001
# 1     1002
# 2     1003
# 3     1004
# 4     1005
# 5     1006
# 6     1007
# 7     1008
# 8     1009
# 9     1010
# 10    1011
# Name: QuestionId, dtype: int64

# %%
def save_submission(result):
    qid = test_df['QuestionId']
    cleaned = pd.Series([
        s.lstrip('\n').removeprefix('Answer:').strip()
        for s in result
    ])
    submission = qid.to_frame()
    submission['Answer'] = cleaned
    assert list(submission.columns) == ['QuestionId', 'Answer']
    assert len(submission) == len(test_df) == 11
    assert submission['QuestionId'].tolist() == test_df['QuestionId'].tolist()
    assert submission['Answer'].str.strip().ne('').all()
    submission.to_csv('/kaggle/working/submission.csv', index=False)
    print(submission)
    print('Saved /kaggle/working/submission.csv')

save_submission(eval)
# Out:
# 0     Screening, iron supplementation with vitamin C...
# 1     Seek urgent paediatric assessment for any feve...
# 2     Heavy bleeding, foul discharge, fever, or seve...
# 3     Validate feelings, keep routines, refer if avo...
# 4     Use nets, eliminate standing water, test fever...
# 5     Daily controller inhaler, daily trigger avoida...
# 6     Half vegetables and fruits, quarter whole grai...
# 7     Finish the full course unless a clinician tell...
# 8     Every ten years or after uncertain vaccination...
# 9       Persistent vomiting, confusion, or dehydration.
# 10           Oral rehydration ORS and safe water first.
# dtype: object
#     QuestionId                                             Answer
# 0         1001  Screening, iron supplementation with vitamin C...
# 1         1002  Seek urgent paediatric assessment for any feve...
# 2         1003  Heavy bleeding, foul discharge, fever, or seve...
# 3         1004  Validate feelings, keep routines, refer if avo...
# 4         1005  Use nets, eliminate standing water, test fever...
# 5         1006  Daily controller inhaler, daily trigger avoida...
# 6         1007  Half vegetables and fruits, quarter whole grai...
# 7         1008  Finish the full course unless a clinician tell...
# 8         1009  Every ten years or after uncertain vaccination...
# 9         1010    Persistent vomiting, confusion, or dehydration.
# 10        1011         Oral rehydration ORS and safe water first.
